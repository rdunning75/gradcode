# %%
import pandas as pd
import numpy as np
from keras.initializers.initializers_v2 import RandomNormal
from numpy import mean
from numpy import std
import keras as ks
import sklearn as skl
import tensorflow as tf
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import train_test_split, cross_val_score, KFold, RepeatedKFold
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasRegressor
from keras.backend import sqrt, mean, square
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler




pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
# tf.enable_eager_execution()
pd.set_option('display.width', 750)

# define min max scaler
scaler = MinMaxScaler()
# transform data
df = pd.read_csv('weather_and_fire_average_30b_7a.csv')
print(df)

stuff = [ "Precip (in)",  "Sol Rad (Ly/day)" ,"Avg Rel Hum (%)", "Avg Wind Speed (mph)", "Avg Soil Temp (F)", "FIRE_"]
df = df.astype({stuff[0]: 'float32'})
# print(df)

X = df[stuff]
y = df["FIRE_SIZE"]
scaledX = scaler.fit_transform(X)

print(scaledX)
# Out:
#      ETo (in)  Precip (in)  Sol Rad (Ly/day)  Avg Vap Pres (mBars)  Avg Air Temp (F)  Avg Rel Hum (%)  Avg Wind Speed (mph)  Wind Run (miles)  Avg Soil Temp (F)  FIRE_SIZE
# 0        0.06         0.00             289.0                   4.6              37.6             61.0                   3.4              81.1               53.6       1.00
# 1        0.05         0.00             267.0                   4.7              34.1             70.0                   1.6              39.2               46.2       1.00
# 2        0.06         0.01             269.0                   6.0              42.9             63.0                   2.0              47.5               49.2       0.10
# 3        0.07         0.00             268.0                   6.1              45.6             59.0                   4.1              98.6               52.5       0.12
# 4        0.06         0.00             289.0                   4.6              37.6             61.0                   3.4              81.1               53.6       1.00
# ..        ...          ...               ...                   ...               ...              ...                   ...               ...                ...        ...
# 899      0.15         0.00             528.0                  10.6              61.0             58.0                   3.1              73.4               67.3     328.00
# 900      0.16         0.00             529.0                  12.5              60.8             69.0                   5.0             119.3               70.3      50.00
# 901      0.12         0.00             521.0                   6.6              41.1             76.0                   1.9              45.4               52.6     200.00
# 902      0.16         0.06             502.0                  10.8              59.3             63.0                   3.7              89.7               61.5    9999.00
# 903      0.14         0.00             380.0                  10.1              67.9             43.0                   2.5              59.1               67.2    3126.00
#
# [904 rows x 10 columns]
# [[0.         0.30293501 0.58064516 0.22222222 0.34856176]
#  [0.         0.27987421 0.67741935 0.05555556 0.22335025]
#  [0.01960784 0.28197065 0.60215054 0.09259259 0.27411168]
#  ...
#  [0.         0.54612159 0.74193548 0.08333333 0.33164129]
#  [0.11764706 0.52620545 0.60215054 0.25       0.4822335 ]
#  [0.         0.39832285 0.38709677 0.13888889 0.5786802 ]]

# %%
def root_mean_squared_error(y_true, y_pred):
    return sqrt(mean(square(y_true - y_pred)))

def root_mean_squared_percent_error(y_true, y_pred):
     rmspe = (sqrt(mean(square((y_true - y_pred) / y_true)))) * 100
     return rmspe

# %%
# print(y)



    #   rmspe = (ks.backend.sqrt(ks.backend.mean(ks.backend.square((y_true - y_pred) / y_true)))) * 100
    # print(type(rmspe))
    # thing = tf.compat.v1.placeholder(tf.float32)
    # with tf.compat.v1.Session() as sess:
    #     sess.run(rmspe.ref(), feed_dict={thing: y_pred})
    # return thing

def ann():
    model = Sequential()
    model.add(Dense(6, input_dim=6, activation='relu'))
    model.add(Dense(128, activation='tanh'))
    model.add(Dense(64, activation='tanh'))

    model.add(Dense(16, activation='tanh'))

    model.add(Dense(1, kernel_initializer='normal', activation='tanh'))
    model.compile(loss=root_mean_squared_percent_error, optimizer='adam', metrics=[root_mean_squared_percent_error,tf.keras.metrics.RootMeanSquaredError()])
    return model



X_train, X_test, Y_train, Y_test = train_test_split(scaledX,y, test_size=0.30)


# rmspeScore = make_scorer(root_mean_squared_percent_error, greater_is_better=False)
model1 = ann()
model1.fit(X_train,Y_train,batch_size=32,epochs=50,verbose=True)
# Out:
# Epoch 1/50
# 764/764 [==============================] - 1s 683us/step - loss: 85.3751 - root_mean_squared_percent_error: 85.3717 - root_mean_squared_error: 14381.8857
# Epoch 2/50
# 764/764 [==============================] - 1s 693us/step - loss: 85.2270 - root_mean_squared_percent_error: 85.2318 - root_mean_squared_error: 14381.8848
# Epoch 3/50
# 764/764 [==============================] - 1s 670us/step - loss: 85.2321 - root_mean_squared_percent_error: 85.2332 - root_mean_squared_error: 14381.8838
# Epoch 4/50
# 764/764 [==============================] - 1s 682us/step - loss: 85.2299 - root_mean_squared_percent_error: 85.2264 - root_mean_squared_error: 14381.8867 0s - loss: 85.2288 - root_mean_squared_percent_error: 85.2288 - root_mean_squared_error: 128
# Epoch 5/50
# 764/764 [==============================] - 1s 696us/step - loss: 85.2249 - root_mean_squared_percent_error: 85.2228 - root_mean_squared_error: 14381.8779
# Epoch 6/50
# 764/764 [==============================] - 1s 696us/step - loss: 85.2125 - root_mean_squared_percent_error: 85.2128 - root_mean_squared_error: 14381.8818 0s - loss: 85.4974 - root_mean_squared_percent_error: 85.4974 - root_mean_squared_error: 13613
# Epoch 7/50
# 764/764 [==============================] - 1s 690us/step - loss: 85.2257 - root_mean_squared_percent_error: 85.2264 - root_mean_squared_error: 14381.8828
# Epoch 8/50
# 764/764 [==============================] - 1s 695us/step - loss: 85.2099 - root_mean_squared_percent_error: 85.2131 - root_mean_squared_error: 14381.8818
# Epoch 9/50
# 764/764 [==============================] - 1s 720us/step - loss: 85.2250 - root_mean_squared_percent_error: 85.2266 - root_mean_squared_error: 14381.8848
# Epoch 10/50
# 764/764 [==============================] - 1s 712us/step - loss: 85.2191 - root_mean_squared_percent_error: 85.2197 - root_mean_squared_error: 14381.8779
# Epoch 11/50
# 764/764 [==============================] - 1s 707us/step - loss: 85.2109 - root_mean_squared_percent_error: 85.2137 - root_mean_squared_error: 14381.8789
# Epoch 12/50
# 764/764 [==============================] - 1s 668us/step - loss: 85.2194 - root_mean_squared_percent_error: 85.2243 - root_mean_squared_error: 14381.8789
# Epoch 13/50
# 764/764 [==============================] - 1s 678us/step - loss: 85.2274 - root_mean_squared_percent_error: 85.2202 - root_mean_squared_error: 14381.8828 0s - loss: 85.1730 - root_mean_squared_percent_error: 85.1730 - root_mean_squared_error: 15111.
# Epoch 14/50
# 764/764 [==============================] - 1s 708us/step - loss: 85.2089 - root_mean_squared_percent_error: 85.1976 - root_mean_squared_error: 14381.8789
# Epoch 15/50
# 764/764 [==============================] - 1s 714us/step - loss: 85.2115 - root_mean_squared_percent_error: 85.2090 - root_mean_squared_error: 14381.8760
# Epoch 16/50
# 764/764 [==============================] - 1s 673us/step - loss: 85.1959 - root_mean_squared_percent_error: 85.1985 - root_mean_squared_error: 14381.8818
# Epoch 17/50
# 764/764 [==============================] - 1s 677us/step - loss: 85.1947 - root_mean_squared_percent_error: 85.1920 - root_mean_squared_error: 14381.8789
# Epoch 18/50
# 764/764 [==============================] - 1s 693us/step - loss: 85.1962 - root_mean_squared_percent_error: 85.1974 - root_mean_squared_error: 14381.8838
# Epoch 19/50
# 764/764 [==============================] - 1s 702us/step - loss: 85.1973 - root_mean_squared_percent_error: 85.1917 - root_mean_squared_error: 14381.8838
# Epoch 20/50
# 764/764 [==============================] - 1s 704us/step - loss: 85.1670 - root_mean_squared_percent_error: 85.1637 - root_mean_squared_error: 14381.8779
# Epoch 21/50
# 764/764 [==============================] - 1s 706us/step - loss: 85.1713 - root_mean_squared_percent_error: 85.1670 - root_mean_squared_error: 14381.8828
# Epoch 22/50
# 764/764 [==============================] - 1s 673us/step - loss: 85.1626 - root_mean_squared_percent_error: 85.1656 - root_mean_squared_error: 14381.8828
# Epoch 23/50
# 764/764 [==============================] - 1s 754us/step - loss: 85.1446 - root_mean_squared_percent_error: 85.1469 - root_mean_squared_error: 14381.8760
# Epoch 24/50
# 764/764 [==============================] - 1s 750us/step - loss: 85.1503 - root_mean_squared_percent_error: 85.1515 - root_mean_squared_error: 14381.8760
# Epoch 25/50
# 764/764 [==============================] - 1s 707us/step - loss: 85.1416 - root_mean_squared_percent_error: 85.1475 - root_mean_squared_error: 14381.8818 0s - loss: 85.1850 - root_mean_squared_percent_error: 85.1850 - root_mean_squared_error: 14132
# Epoch 26/50
# 764/764 [==============================] - 1s 719us/step - loss: 85.1569 - root_mean_squared_percent_error: 85.1551 - root_mean_squared_error: 14381.8838
# Epoch 27/50
# 764/764 [==============================] - 1s 706us/step - loss: 85.1338 - root_mean_squared_percent_error: 85.1383 - root_mean_squared_error: 14381.8838
# Epoch 28/50
# 764/764 [==============================] - 1s 695us/step - loss: 85.1349 - root_mean_squared_percent_error: 85.1360 - root_mean_squared_error: 14381.8799
# Epoch 29/50
# 764/764 [==============================] - 1s 667us/step - loss: 85.1397 - root_mean_squared_percent_error: 85.1422 - root_mean_squared_error: 14381.8789
# Epoch 30/50
# 764/764 [==============================] - 1s 698us/step - loss: 85.1445 - root_mean_squared_percent_error: 85.1450 - root_mean_squared_error: 14381.8828
# Epoch 31/50
# 232/764 [========>.....................] - ETA: 0s - loss: 85.2899 - root_mean_squared_percent_error: 85.2899 - root_mean_squared_error: 14099.8086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10096/3299010926.py in <module>
#      29 # rmspeScore = make_scorer(root_mean_squared_percent_error, greater_is_better=False)
#      30 model1 = ann()
# ---> 31 model1.fit(X_train,Y_train,batch_size=32,epochs=50,verbose=True)
#      32
#      33
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def ann2():
    model = Sequential()
    model.add(Dense(6, input_dim=6, activation='relu'))
    model.add(Dense(128, activation='tanh'))
    model.add(Dense(64, activation='tanh'))

    model.add(Dense(16, activation='tanh'))

    model.add(Dense(1, kernel_initializer='normal', activation='tanh'))
    model.compile(loss="mse", optimizer='adam', metrics=['mean_squared_error'])
    return model

model2 = ann2()
model2.fit(X_train,Y_train,batch_size=64,epochs=50,verbose=True)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 1s 621us/step - loss: 206836704.0000 - mean_squared_error: 206836704.0000
# Epoch 2/50
# 382/382 [==============================] - 0s 648us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000
# Epoch 3/50
# 382/382 [==============================] - 0s 571us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000
# Epoch 4/50
# 382/382 [==============================] - 0s 568us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 5/50
# 382/382 [==============================] - 0s 632us/step - loss: 206836480.0000 - mean_squared_error: 206836480.0000
# Epoch 6/50
# 382/382 [==============================] - 0s 643us/step - loss: 206836384.0000 - mean_squared_error: 206836384.0000
# Epoch 7/50
# 382/382 [==============================] - 0s 629us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000
# Epoch 8/50
# 382/382 [==============================] - 0s 598us/step - loss: 206836384.0000 - mean_squared_error: 206836384.0000
# Epoch 9/50
# 382/382 [==============================] - 0s 670us/step - loss: 206836480.0000 - mean_squared_error: 206836480.0000
# Epoch 10/50
# 382/382 [==============================] - 0s 646us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 11/50
# 382/382 [==============================] - 0s 668us/step - loss: 206836336.0000 - mean_squared_error: 206836336.0000
# Epoch 12/50
# 382/382 [==============================] - 0s 611us/step - loss: 206836448.0000 - mean_squared_error: 206836448.0000
# Epoch 13/50
# 382/382 [==============================] - 0s 674us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 14/50
# 382/382 [==============================] - 0s 662us/step - loss: 206836384.0000 - mean_squared_error: 206836384.0000
# Epoch 15/50
# 382/382 [==============================] - 0s 622us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 16/50
# 382/382 [==============================] - 0s 596us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 17/50
# 382/382 [==============================] - 0s 685us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 18/50
# 382/382 [==============================] - 0s 654us/step - loss: 206836480.0000 - mean_squared_error: 206836480.0000
# Epoch 19/50
# 382/382 [==============================] - 0s 656us/step - loss: 206836352.0000 - mean_squared_error: 206836352.0000
# Epoch 20/50
# 382/382 [==============================] - 0s 660us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000
# Epoch 21/50
# 382/382 [==============================] - 0s 652us/step - loss: 206836352.0000 - mean_squared_error: 206836352.0000
# Epoch 22/50
# 382/382 [==============================] - 0s 639us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 23/50
# 382/382 [==============================] - 0s 683us/step - loss: 206836528.0000 - mean_squared_error: 206836528.0000
# Epoch 24/50
# 382/382 [==============================] - 0s 669us/step - loss: 206836512.0000 - mean_squared_error: 206836512.0000
# Epoch 25/50
# 382/382 [==============================] - 0s 676us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 26/50
# 382/382 [==============================] - 0s 669us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 27/50
# 382/382 [==============================] - 0s 682us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 28/50
# 382/382 [==============================] - 0s 661us/step - loss: 206836512.0000 - mean_squared_error: 206836512.0000
# Epoch 29/50
# 382/382 [==============================] - 0s 664us/step - loss: 206836320.0000 - mean_squared_error: 206836320.0000
# Epoch 30/50
# 382/382 [==============================] - 0s 637us/step - loss: 206836512.0000 - mean_squared_error: 206836512.0000
# Epoch 31/50
# 382/382 [==============================] - 0s 688us/step - loss: 206836512.0000 - mean_squared_error: 206836512.00000s - loss: 196568400.0000 - mean_squared_error: 196568
# Epoch 32/50
# 382/382 [==============================] - 0s 665us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 33/50
# 382/382 [==============================] - 0s 682us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 34/50
# 382/382 [==============================] - 0s 679us/step - loss: 206836512.0000 - mean_squared_error: 206836512.0000
# Epoch 35/50
# 382/382 [==============================] - 0s 653us/step - loss: 206836384.0000 - mean_squared_error: 206836384.0000
# Epoch 36/50
# 382/382 [==============================] - 0s 684us/step - loss: 206836352.0000 - mean_squared_error: 206836352.0000
# Epoch 37/50
# 382/382 [==============================] - 0s 677us/step - loss: 206836336.0000 - mean_squared_error: 206836336.0000
# Epoch 38/50
# 382/382 [==============================] - 0s 659us/step - loss: 206836448.0000 - mean_squared_error: 206836448.0000
# Epoch 39/50
# 382/382 [==============================] - 0s 655us/step - loss: 206836352.0000 - mean_squared_error: 206836352.0000s: 176925552.0000 - mean_squared_error: 176925
# Epoch 40/50
# 382/382 [==============================] - 0s 630us/step - loss: 206836448.0000 - mean_squared_error: 206836448.0000
# Epoch 41/50
# 382/382 [==============================] - 0s 629us/step - loss: 206836528.0000 - mean_squared_error: 206836528.0000
# Epoch 42/50
# 382/382 [==============================] - 0s 647us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 43/50
# 382/382 [==============================] - 0s 652us/step - loss: 206836400.0000 - mean_squared_error: 206836400.0000
# Epoch 44/50
# 382/382 [==============================] - 0s 630us/step - loss: 206836320.0000 - mean_squared_error: 206836320.0000
# Epoch 45/50
# 382/382 [==============================] - 0s 674us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 46/50
# 382/382 [==============================] - 0s 596us/step - loss: 206836464.0000 - mean_squared_error: 206836464.0000
# Epoch 47/50
# 382/382 [==============================] - 0s 672us/step - loss: 206836384.0000 - mean_squared_error: 206836384.0000
# Epoch 48/50
# 382/382 [==============================] - 0s 635us/step - loss: 206836528.0000 - mean_squared_error: 206836528.0000
# Epoch 49/50
# 382/382 [==============================] - 0s 671us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000
# Epoch 50/50
# 382/382 [==============================] - ETA: 0s - loss: 215321840.0000 - mean_squared_error: 215321840.00 - 0s 659us/step - loss: 206836416.0000 - mean_squared_error: 206836416.0000

# %%
from sklearn.metrics import mean_squared_error

# RMSPE????

# pred_train = model1.predict(X_train)
# print(root_mean_squared_percent_error(Y_train.to_numpy(),pred_train))


# pred = model1.predict(X_test)
# print(root_mean_squared_percent_error(Y_test.to_numpy(),pred))




#RMSE

pred = model2.predict(X_test)
pred_train = model2.predict(X_train)

print(np.sqrt(mean_squared_error(Y_train,pred_train)))
print(np.sqrt(mean_squared_error(Y_test,pred))) 

thing = 





loss2, RootMeanSquaredError2 = model2.evaluate(X_test, Y_test, verbose=0)
# print('Model 1')
# print('RMSPE = ', RMSPE1)
# print('RootMeanSquaredError =',RootMeanSquaredError1)


print('Model 2')
print('RMSE = ', loss2)
print('RootMeanSquaredError =',RootMeanSquaredError2)
# Out:
# 14381.809412513912
# 13444.689114955949
# Model 2
# RMSE =  180759696.0
# RootMeanSquaredError = 180759696.0

# %% [raw]
# # import matplotlib.pyplot as plt
# # test_predictions = model2.predict(X_test)
# # Y_test_array = Y_test.to_numpy()
# # print(test_predictions)
# # print(Y_test_array)
#
# # # p1 = max(max(predicted_value), max(true_value))
# # plt.scatter(test_predictions,Y_test_array)
# # # p1 = max(max(test_predictions), max(Y_test_array))
# # # p2 = min(min(test_predictions), min(Y_test_array))
# # plt.xlabel('Predictions', fontsize=15)
# # plt.ylabel('Y_test_array', fontsize=15)
# # # plt.axis('equal')
