# %%
import pandas as pd
import numpy as np
from keras.initializers.initializers_v2 import RandomNormal
from numpy import mean
from numpy import std
import keras as ks
import sklearn as skl
import tensorflow as tf
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import train_test_split, cross_val_score, KFold, RepeatedKFold
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasRegressor
from keras.backend import sqrt, mean, square
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler




pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
# tf.enable_eager_execution()
pd.set_option('display.width', 750)

# define min max scaler
scaler = MinMaxScaler()
# transform data

df = pd.read_csv('weather_and_fire.csv')
stuff = ["ETo (in)", "Precip (in)",  "Sol Rad (Ly/day)" ,"Avg Vap Pres (mBars)" ,"Avg Air Temp (F)" ,"Avg Rel Hum (%)", "Avg Wind Speed (mph)","Wind Run (miles)", "Avg Soil Temp (F)"]
df = df.astype({stuff[0]: 'float32'})
# print(df)

X = df[stuff]
y = df["FIRE_SIZE"]
scaledX = scaler.fit_transform(X)

print(scaledX)
# Out:
# [[0.43902441 0.         0.07766697 ... 0.11801242 0.11645963 0.55744678]
#  [0.43902441 0.         0.08129344 ... 0.14285714 0.14078675 0.81578947]
#  [0.29268292 0.         0.05605923 ... 0.11801242 0.11878882 0.79934211]
#  ...
#  [0.31707316 0.         0.06542762 ... 0.13664596 0.13328157 0.61842105]
#  [0.31707316 0.         0.06270777 ... 0.1552795  0.15372671 0.62171053]
#  [0.31707316 0.         0.06331218 ... 0.16149068 0.1563147  0.61513158]]

# %%
def root_mean_squared_error(y_true, y_pred):
    return sqrt(mean(square(y_true - y_pred)))

def root_mean_squared_percent_error(y_true, y_pred):
     rmspe = (sqrt(mean(square((y_true - y_pred) / y_true)))) * 100
     return rmspe

# %%
# print(y)



    #   rmspe = (ks.backend.sqrt(ks.backend.mean(ks.backend.square((y_true - y_pred) / y_true)))) * 100
    # print(type(rmspe))
    # thing = tf.compat.v1.placeholder(tf.float32)
    # with tf.compat.v1.Session() as sess:
    #     sess.run(rmspe.ref(), feed_dict={thing: y_pred})
    # return thing

def ann():
    model = Sequential()
    model.add(Dense(64, input_dim=9, activation='relu'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(1, kernel_initializer='normal', activation='tanh'))
    model.compile(loss=root_mean_squared_percent_error, optimizer='adam', metrics=[root_mean_squared_percent_error,tf.keras.metrics.RootMeanSquaredError()])
    return model



X_train, X_test, Y_train, Y_test = train_test_split(scaledX,y, test_size=0.20)


# rmspeScore = make_scorer(root_mean_squared_percent_error, greater_is_better=False)
model1 = ann()
model1.fit(X_train,Y_train,batch_size=16,epochs=100,verbose=True)
# Out:
# Epoch 1/100
# 2764/2764 [==============================] - 3s 516us/step - loss: 85.7934 - root_mean_squared_percent_error: 85.7942 - root_mean_squared_error: 14085.3203
# Epoch 2/100
# 2012/2764 [====================>.........] - ETA: 0s - loss: 85.2745 - root_mean_squared_percent_error: 85.2745 - root_mean_squared_error: 14306.7666
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17452/1831223167.py in <module>
#      25 # rmspeScore = make_scorer(root_mean_squared_percent_error, greater_is_better=False)
#      26 model1 = ann()
# ---> 27 model1.fit(X_train,Y_train,batch_size=16,epochs=100,verbose=True)
#      28
#      29
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def ann2():
    model = Sequential()
    model.add(Dense(64, input_dim=9, activation='relu'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(1, kernel_initializer='normal', activation='tanh'))
    model.compile(loss=tf.keras.metrics.RootMeanSquaredError(), optimizer='adam',)
    return model

model2 = ann2()
model2.fit(X_train,Y_train,batch_size=32,epochs=100,verbose=True)
# Out:
# Epoch 1/100
# 1382/1382 [==============================] - 1s 475us/step - loss: 5517.2495 - root_mean_squared_error: 13947.1074
# Epoch 2/100
# 1382/1382 [==============================] - 1s 524us/step - loss: 5449.1719 - root_mean_squared_error: 13947.1055
# Epoch 3/100
# 1382/1382 [==============================] - 1s 472us/step - loss: 5484.2588 - root_mean_squared_error: 13947.1084
# Epoch 4/100
# 1382/1382 [==============================] - 1s 497us/step - loss: 5491.2563 - root_mean_squared_error: 13947.1074
# Epoch 5/100
# 1382/1382 [==============================] - 1s 491us/step - loss: 5474.1885 - root_mean_squared_error: 13947.1055
# Epoch 6/100
# 1382/1382 [==============================] - 1s 527us/step - loss: 5544.4248 - root_mean_squared_error: 13947.1045
# Epoch 7/100
# 1382/1382 [==============================] - 1s 503us/step - loss: 5535.7720 - root_mean_squared_error: 13947.1045
# Epoch 8/100
# 1382/1382 [==============================] - 1s 506us/step - loss: 5441.8071 - root_mean_squared_error: 13947.1074
# Epoch 9/100
# 1382/1382 [==============================] - 1s 493us/step - loss: 5495.8682 - root_mean_squared_error: 13947.1074
# Epoch 10/100
# 1382/1382 [==============================] - 1s 498us/step - loss: 5463.7856 - root_mean_squared_error: 13947.1035
# Epoch 11/100
# 1382/1382 [==============================] - 1s 544us/step - loss: 5360.7339 - root_mean_squared_error: 13947.1084
# Epoch 12/100
# 1382/1382 [==============================] - 1s 494us/step - loss: 5488.1328 - root_mean_squared_error: 13947.0977
# Epoch 13/100
# 1382/1382 [==============================] - 1s 517us/step - loss: 5423.9619 - root_mean_squared_error: 13947.0996
# Epoch 14/100
# 1382/1382 [==============================] - 1s 572us/step - loss: 5493.6445 - root_mean_squared_error: 13947.1074
# Epoch 15/100
# 1382/1382 [==============================] - 1s 586us/step - loss: 5534.4731 - root_mean_squared_error: 13947.1025
# Epoch 16/100
# 1382/1382 [==============================] - 1s 566us/step - loss: 5446.6997 - root_mean_squared_error: 13947.1025
# Epoch 17/100
# 1382/1382 [==============================] - 1s 505us/step - loss: 5403.2231 - root_mean_squared_error: 13947.1016
# Epoch 18/100
# 1382/1382 [==============================] - 1s 620us/step - loss: 5524.5928 - root_mean_squared_error: 13947.1025
# Epoch 19/100
# 1382/1382 [==============================] - 1s 524us/step - loss: 5516.6172 - root_mean_squared_error: 13947.1074
# Epoch 20/100
# 1382/1382 [==============================] - 1s 546us/step - loss: 5470.6934 - root_mean_squared_error: 13947.1055
# Epoch 21/100
# 1382/1382 [==============================] - 1s 535us/step - loss: 5506.5767 - root_mean_squared_error: 13947.10550s - loss: 5476.8179 - root_mean_squ
# Epoch 22/100
# 1382/1382 [==============================] - 1s 529us/step - loss: 5507.7866 - root_mean_squared_error: 13947.1094
# Epoch 23/100
# 1382/1382 [==============================] - 1s 511us/step - loss: 5594.9014 - root_mean_squared_error: 13947.1025
# Epoch 24/100
# 1382/1382 [==============================] - 1s 522us/step - loss: 5435.0381 - root_mean_squared_error: 13947.1055
# Epoch 25/100
# 1382/1382 [==============================] - 1s 503us/step - loss: 
100
# 1382/1382 [==============================] - 1s 503us/step - loss: 5451.5962 - root_mean_squared_error: 13947.1045
# Epoch 87/100
# 1382/1382 [==============================] - 1s 507us/step - loss: 5523.0532 - root_mean_squared_error: 13947.1094
# Epoch 88/100
# 1382/1382 [==============================] - 1s 488us/step - loss: 5445.2847 - root_mean_squared_error: 13947.1113
# Epoch 89/100
# 1382/1382 [==============================] - 1s 499us/step - loss: 5498.6470 - root_mean_squared_error: 13947.1074
# Epoch 90/100
# 1382/1382 [==============================] - 1s 520us/step - loss: 5472.6895 - root_mean_squared_error: 13947.0996
# Epoch 91/100
# 1382/1382 [==============================] - 1s 494us/step - loss: 5540.3428 - root_mean_squared_error: 13947.1025
# Epoch 92/100
# 1382/1382 [==============================] - 1s 505us/step - loss: 5476.1118 - root_mean_squared_error: 13947.1055
# Epoch 93/100
# 1382/1382 [==============================] - 1s 497us/step - loss: 5453.2725 - root_mean_squared_error: 13947.1045
# Epoch 94/100
# 1382/1382 [==============================] - 1s 480us/step - loss: 5530.1079 - root_mean_squared_error: 13947.1025
# Epoch 95/100
# 1382/1382 [==============================] - 1s 501us/step - loss: 5480.1670 - root_mean_squared_error: 13947.1035
# Epoch 96/100
# 1382/1382 [==============================] - 1s 533us/step - loss: 5466.7295 - root_mean_squared_error: 13947.1045
# Epoch 97/100
# 1382/1382 [==============================] - 1s 503us/step - loss: 5562.6709 - root_mean_squared_error: 13947.1104
# Epoch 98/100
# 1382/1382 [==============================] - 1s 519us/step - loss: 5473.1533 - root_mean_squared_error: 13947.1055
# Epoch 99/100
# 1382/1382 [==============================] - 1s 500us/step - loss: 5546.4604 - root_mean_squared_error: 13947.1074
# Epoch 100/100
# 1382/1382 [==============================] - 1s 544us/step - loss: 5486.8091 - root_mean_squared_error: 13947.1074

# %%
loss1, RMSPE1, RootMeanSquaredError1 = model1.evaluate(X_test, Y_test, verbose=0)
loss2, RootMeanSquaredError2 = model2.evaluate(X_test, Y_test, verbose=0)
print('Model 1')
print('RMSPE = ', RMSPE1)
print('RootMeanSquaredError =',RootMeanSquaredError1)

print('Model 2')
print('RMSE = ', loss)
print('RootMeanSquaredError =',RootMeanSquaredError2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17452/1090896390.py in <module>
#       1 loss1, RMSPE1, RootMeanSquaredError1 = model1.evaluate(X_test, Y_test, verbose=0)
# ----> 2 loss2, RootMeanSquaredError2 = model2.evaluate(X_test, Y_test, verbose=0)
#       3 print('Model 1')
#       4 print('RMSPE = ', RMSPE1)
#       5 print('RootMeanSquaredError =',RootMeanSquaredError1)
#
# ValueError: too many values to unpack (expected 2)

# %%
import matplotlib.pyplot as plt
test_predictions = model.predict(X_test)
Y_test_array = Y_test.to_numpy()
print(test_predictions)
print(Y_test_array)

# p1 = max(max(predicted_value), max(true_value))
plt.scatter(test_predictions,Y_test_array)
# p1 = max(max(test_predictions), max(Y_test_array))
# p2 = min(min(test_predictions), min(Y_test_array))
plt.xlabel('Predictions', fontsize=15)
plt.ylabel('Y_test_array', fontsize=15)
# plt.axis('equal')
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# [1.00e-02 1.00e-01 4.86e+02 ... 1.00e-01 1.00e-01 7.50e-01]
# Text(0, 0.5, 'Y_test_array')
